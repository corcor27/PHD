# %%
import numpy as np
from sklearn.datasets import load_iris, load_digits
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import umap
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

DATADIR = "/home/cot12/Documents/test-folder"
CATEGORIES = ["M","B"]

sns.set(style='white', context='notebook', rc={'figure.figsize': (14, 10)})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-ac2824d483cb> in <module>
#       9 import matplotlib.pyplot as plt
#      10 import os
# ---> 11 import opencv
#      12
#      13 DATADIR = "/home/cot12/Documents/test-folder"
#
# ModuleNotFoundError: No module named 'opencv'

# %%
IMG_SIZE = 1000

training_data = []

def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
            new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
            training_data.append([new_array, class_num])
        
create_training_data()

# %%
for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap = "gray")
        plt.show()
        break
    break

# %%
digits_df = pd.DataFrame(img_array.data[:,:10])
digits_df['digit'] = pd.Series(img_array.target).map(lambda x: 'Digit {}'.format(x))
sns.pairplot(digits_df, hue = 'digit', palette = 'Spectral');
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-20-8db2aa8a4082> in <module>
# ----> 1 digits_df = pd.DataFrame(img_array.data[:,:10])
#       2 digits_df['digit'] = pd.Series(img_array.target).map(lambda x: 'Digit {}'.format(x))
#       3 sns.pairplot(digits_df, hue = 'digit', palette = 'Spectral');
#
# NotImplementedError: multi-dimensional slicing is not implemented
