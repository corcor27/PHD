# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import ndimage
import os

path = '/home/cot12/Documents/ddsm/ddsm-samples/'
ren = os.listdir(path)
length = len(ren)

keypoints = np.zeros((length, 9))

for m in range(0, length):
    addition = os.path.join(path,ren[m])
    image = cv2.imread(addition,0)
    Beginning_image = image
    print (ren[m])
   

    def Image_check_x(image):
        p = image.shape[0]
        if ((p+3)/4) != int((p+3)/4):
            if ((p+2)/4) != int((p+2)/4):
                if ((p+1)/4) != int((p+1)/4):
                    return p
                else:
                    return p+1
            else:
                return p+2
        else:
            return p+3



    def Image_check_y(image):
        p = image.shape[1]
        if ((p+3)/4) != int((p+3)/4):
            if ((p+2)/4) != int((p+2)/4):
                if ((p+1)/4) != int((p+1)/4):
                    return p
                else:
                    return p+1
            else:
                return p+2
        else:
            return p+3



    
    
    q = int(Image_check_x(Beginning_image))
    u = int(Image_check_y(Beginning_image))
    beginning_image = cv2.resize(Beginning_image,(u,q))
    normal = beginning_image

    pyrlvl1 = np.zeros((normal.shape[0], normal.shape[1]))
    pyrlvl2 = np.zeros((normal.shape[0], normal.shape[1]))
    pyrlvl3 = np.zeros((normal.shape[0], normal.shape[1]))
    pyrlvlx = np.zeros((q, u))
    pyrlvly = np.zeros((q, u))
    pyrlvlx[:,:] = ndimage.sobel(normal, 0)
    pyrlvly[:,:] = ndimage.sobel(normal, 1)
    Grmaglvl = (((pyrlvlx)**2)+((pyrlvly)**2))**0.5
    
    #pyrlvl1 = normal
    #pyrlvl2 = ndimage.filters.gaussian_filter(normal, 10)
    #pyrlvl3 = pyrlvl2 - pyrlvl1
    #pyrlvl4 = pyrlvl3*100
    plt.imshow(Grmaglvl, cmap = 'gray')
    plt.show()
# Out:
# p_0331_1.RIGHT_MLO_b1.tif
# p_1673_1.RIGHT_MLO_b4.tif
# p_0492_1.RIGHT_MLO_b2.tif
# p_0188_1.RIGHT_MLO_b1.tif
# p_4563_1.RIGHT_MLO_b2.tif
# p_3057_1.RIGHT_MLO_b3.tif
# p_3653_1.RIGHT_MLO_b4.tif
# p_3063_1.RIGHT_MLO_b3.tif
# p_0506_1.RIGHT_MLO_b2.tif
# p_4000_1.RIGHT_MLO_b3.tif
# p_1671_1.RIGHT_MLO_b2.tif
# p_1988_1.RIGHT_MLO_b2.tif
# p_4072_1.RIGHT_MLO_b1.tif
